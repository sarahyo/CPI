# %%
import os
import pandas as pd
import json
from pandas import json_normalize
from skimpy import skim
import numpy as np
import plotly_express as px
pd.set_option('display.float_format', lambda x: '{:.0f}'.format(x))

# %%
columns = [
    'categories', "manufacturer", "title", "lastUpdate", "lastPriceChange",
    "rootCategory", "productType", "parentAsin", "variationCSV", "asin",
    "type", "hasReviews", "trackingSince", "brand", "productGroup", "partNumber",
    "model", "color", "edition", "isAdultProduct", "isEligibleForTradeIn",
    "isEligibleForSuperSaverShipping", "offers", "buyBoxSellerIdHistory",
    "isRedirectASIN", "isSNS", "author", "binding", "numberOfItems",
    "numberOfPages", "publicationDate", "releaseDate", "languages",
    "lastRatingUpdate", "size", "frequentlyBoughtTogether", "promotions",
    "coupon", "categoryTree"
]

path_to_json_files = '../out/'
df_list = []

for filename in os.listdir(path_to_json_files):
    if filename.endswith('.json'):
        with open(os.path.join(path_to_json_files, filename)) as user_file:
            parsed_json = json.load(user_file)
        if 'products' in parsed_json:
            df = json_normalize(parsed_json['products'])
            df1 = df[columns]
            df_list.append(df1)

combined_df = pd.concat(df_list, ignore_index=True)

# combined_df.to_csv('result_8000.csv')

# %%
columns2 = [
    'categories', "lastUpdate", "lastPriceChange",
    "rootCategory", "productType", "parentAsin", "asin",
    "type", "hasReviews", "trackingSince", "brand", "productGroup", "partNumber",
    "edition", "isAdultProduct", "isEligibleForTradeIn",
    "isEligibleForSuperSaverShipping", "offers", "buyBoxSellerIdHistory",
    "isRedirectASIN", "isSNS", "author", "binding", "publicationDate", "releaseDate", "languages",
    "frequentlyBoughtTogether", "promotions", "coupon", "categoryTree"
]

test = combined_df[columns2]

# %%
category = test[['productGroup', 'asin', 'categories', 'categoryTree', "rootCategory"]]

# %%
filters = pd.read_csv('full_filtered_subcategories.csv')

# %%
nodid = list(filters['nodeID'])
nodepath = list(filters['nodePath'])

# %%
import pandas as pd

cats = []

for i, ids in enumerate(nodid):
    for j in range(len(category['categories'])):
        if ids in category['categories'][j]:
            cats.append((nodepath[i], ids, category['asin'][j]))
            

cats_df = pd.DataFrame(cats, columns=['nodepath', 'nodeID', 'asin'])

# %%
cats_df
# Out:
#                                               nodepath     nodeID        asin
# 0                                       Home & Kitchen    1063498  B001U8868Y
# 1                                       Home & Kitchen    1063498  B0013018K2
# 2                                       Home & Kitchen    1063498  B002VFDWAC
# 3                                       Home & Kitchen    1063498  B00C4TR1RA
# 4                                       Home & Kitchen    1063498  B002SVKK7M
# ..                                                 ...        ...         ...
# 763  Home & Kitchen/Storage & Organization/Trash, R... 2422453011  B001BVFO7Q
# 764  Home & Kitchen/Storage & Organization/Trash, R... 2422453011  B001AIFL2S
# 765  Home & Kitchen/Storage & Organization/Trash, R... 2422453011  B0031M9H30
# 766  Home & Kitchen/Storage & Organization/Trash, R... 2422453011  B002Q84N8O
# 767                            Home & Kitchen/Wall Art    3736081  B009GIFAQG
#
# [768 rows x 3 columns]

# %%
result=category.merge(cats_df, on = 'asin', how = 'left')

# %%
result.to_csv('filter_merge_categories.csv')

# %%
result
# Out:
#           productGroup        asin  \
# 0                 Home  B00902X5II
# 1                 Home  B001DNGSCM
# 2              Kitchen  B001UK1BM0
# 3                 Home  B0047DVJWY
# 4              Kitchen  B007ME4WJ2
# ...                ...         ...
# 8737              Home  B0041OFLRS
# 8738  Home Improvement  B0041HYB9E
# 8739           Kitchen  B007G6MX2E
# 8740           Kitchen  B003HEW8TC
# 8741           Kitchen  B004NEHZDO
#
#                                              categories  \
# 0                      [3732781, 18715717011, 13900821]
# 1     [3737601, 23772848011, 23705309011, 1792302001...
# 2                                    [289755, 13900821]
# 3                                   [3735611, 13900821]
# 4                    [119011811011, 15850311, 13900821]
# ...                                                 ...
# 8737                               [14058581, 13900821]
# 8738  [3736241, 23682369011, 23689407011, 1130388920...
# 8739                  [77182869011, 14067421, 13900821]
# 8740                           [77198753011, 376928011]
# 8741                   [24016789011, 3744021, 13900821]
#
#                                            categoryTree  rootCategory  \
# 0     [{'catId': 1055398, 'name': 'Home & Kitchen'},...       1055398
# 1     [{'catId': 1055398, 'name': 'Home & Kitchen'},...       1055398
# 2     [{'catId': 1055398, 'name': 'Home & Kitchen'},...       1055398
# 3     [{'catId': 1055398, 'name': 'Home & Kitchen'},...       1055398
# 4     [{'catId': 265523, 'name': 'Stores'}, {'catId'...        265523
# ...                                                 ...           ...
# 8737  [{'catId': 1055398, 'name': 'Home & Kitchen'},...       1055398
# 8738  [{'catId': 1055398, 'name': 'Home & Kitchen'},...       1055398
# 8739  [{'catId': 265523, 'name': 'Stores'}, {'catId'...        265523
# 8740  [{'catId': 265523, 'name': 'Stores'}, {'catId'...        265523
# 8741  [{'catId': 265523, 'name': 'Stores'}, {'catId'...        265523
#
#                                                nodepath  nodeID
# 0                                                   NaN     NaN
# 1     Home & Kitchen/Heating, Cooling & Air Quality/... 3737601
# 2     Home & Kitchen/Kitchen & Dining/Kitchen Utensi...  289755
# 3                                                   NaN     NaN
# 4                                                   NaN     NaN
# ...                                                 ...     ...
# 8737                                                NaN     NaN
# 8738                                                NaN     NaN
# 8739                                                NaN     NaN
# 8740                                                NaN     NaN
# 8741                                                NaN     NaN
#
# [8742 rows x 7 columns]
